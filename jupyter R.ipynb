# %%
print(getwd())
data <- read.csv(file="arrests_national.csv")
# Out:
# [1] "/home/crawford/Desktop/Code/crime_stats"
#  [1] 10662252 10797088 11205833 11302102 12196959 12408899 13120947 13687241
#  [9] 14005615 14209365 14380370 14094186 13938071 13639479 13741438 13699254
# [17] 13980297 14031070 14528300 15284300 15168100 15119800
# Plot with title “Total Arrests per Year”

# %%
data[,2]
head(data)
# Out:
#  [1] 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 2005 2004 2003 2002
# [16] 2001 2000 1999 1998 1997 1996 1995
#   id year population total_arrests homicide rape  robbery aggravated_assault
# 1 1  2016 323127513  10662252      11788    23632  95754  383977
# 2 2  2015 320896618  10797088      11092    22863  95572  376154
# 3 3  2014 318907401  11205833      10571    21007  94403  372685
# 4 4  2013 316497531  11302102      10231    16863  94406  358860
# 5 5  2012 313873685  12196959      11075    18098 103661  388362
# 6 6  2011 311587816  12408899      10832    19491 106674  397707
#   burglary larceny ⋯ gambling against_family dui     liquor_laws drunkenness
# 1 207325   1050058 ⋯ 3705      88748         1017808 234899      376433
# 2 216010   1160390 ⋯ 4825      94837         1089171 266250      405880
# 3 237974   1238190 ⋯ 5637     102336         1117852 321125      414854
# 4 252629   1231580 ⋯ 6024     101247         1166824 354872      443527
# 5 283582   1282352 ⋯ 7868     107018         1282957 441532      511271
# 6 296707   1264986 ⋯ 8596     116723         1215077 500648      534218
#   disorderly_conduct vagrancy other   suspicion curfew_loitering
# 1 369733             24851    3254871  576      34176
# 2 386078             25151    3218880 1389      44802
# 3 436014             27380    3274430 1310      53654
# 4 467993             25755    3282651 1096      56371
# 5 543995             27003    3448856 1532      70190
# 6 582158             29203    3532195 1424      76942

# %%
data$total_arrests
options(scipen=999)
barplot(data$total_arrests, names.arg=data$year, xlab="Year", ylab="Total Arrests", main="Total Arrests per Year")
# Out:
#  [1] 10662252 10797088 11205833 11302102 12196959 12408899 13120947 13687241
#  [9] 14005615 14209365 14380370 14094186 13938071 13639479 13741438 13699254
# [17] 13980297 14031070 14528300 15284300 15168100 15119800
# Plot with title “Total Arrests per Year”
